# %%
import pandas as pd

# %%
# !chcp 65001
# Out:
# /usr/bin/sh: 1: chcp: not found

# %%
# !dir
# Out:
# bus_stops.csv	 env				Untitled.ipynb
# Bus_stops.ipynb  Pandas_Series_DataFrame.ipynb

# %%
stations = pd.read_csv(open('bus_stops.csv', 'r', encoding='cp1251'),sep=';')

# %%
#Справка по функции или навести на функцию и нажать 'shift' + 'tab' + 'tab'
# ?pd.read_csv

# %%
#Первые 10 строк
stations.head(10)
# Out:
#    ID                                               Name Longitude_WGS84  \
# 0   7  «Дербеневская наб.», 3-й Дербеневский переулок...      37.6551636
# 1  11  «Наб. Тараса Шевченко», набережная Тараса Шевч...     37.57240854
# 2  12  «Наб. Тараса Шевченко», набережная Тараса Шевч...     37.57271647
# 3  27                «ВКНЦ», 3-я Черепковская улица (27)     37.37550932
# 4  33      «Новосущевская ул.», улица Сущёвский Вал (33)     37.60337594
# 5  35          «Керамический пр.», Дубнинская улица (35)     37.55724554
# 6  36                «Ин-т Стали», Дубнинская улица (36)     37.55729147
# 7  37                «Мкр. Дубки», Дубнинская улица (37)     37.55730686
# 8  38                «Д/к Юность», Дубнинская улица (38)     37.55736439
# 9  39  «Баскетбольная школа», улица 800-летия Москвы ...     37.55636146
#
#   Latitude_WGS84                      Street  \
# 0    55.72566817   3-й Дербеневский переулок
# 1    55.74944352  набережная Тараса Шевченко
# ...

# %%
#Группировака по Street
st_count = stations.groupby(['Street']).size()

# %%
st_count
# Out:
# Street
# 1-й Ботанический проезд           1
# 1-й Боткинский проезд             2
# 1-й Варшавский проезд             2
# 1-й Вешняковский проезд           2
# 1-й Войковский проезд             2
# 1-й Волоколамский проезд          4
# 1-й Дачно-Мещерский проезд        4
# 1-й Дербеневский переулок         3
# 1-й Западный проезд               2
# 1-й Капотнинский проезд          13
# 1-й Кожуховский проезд            1
# 1-й Котляковский переулок         2
# 1-й Красногвардейский проезд      5
# 1-й Красногорский проезд          1
# 1-й Краснокурсантский проезд      2
# 1-й Лесной переулок               1
# 1-й Магистральный тупик           3
# 1-й Миргородский переулок         2
# 1-й Митинский переулок            6
# 1-й Нагатинский проезд            2
# 1-й Новоподмосковный переулок     2
# 1-й Пенягинский проезд            5
# 1-й Поперечный проезд             2
# 1-й Рощинский проезд              3
# 1-й Сетуньский проезд             2
# 1-й Силикатный проезд             7
# ...

# %%
#Тип объекта
type(st_count)
# Out:
# pandas.core.series.Series

# %%
#ascending - порядок сортировки, inplace - сохранить результат в ту же переменную
st_count.sort_values(ascending=False, inplace=True)

# %%
st_count
# Out:
# Street
# проезд без названия            510
# Варшавское шоссе               160
# Калужское шоссе                142
# шоссе Энтузиастов               85
# Боровское шоссе                 79
# проспект Мира                   75
# Дмитровское шоссе               74
# Ленинский проспект              70
# Чертановская улица              64
# проспект Вернадского            63
# Каширское шоссе                 60
# Профсоюзная улица               55
# Ленинградское шоссе             54
# Центральная улица               50
# Волгоградский проспект          50
# Волоколамское шоссе             46
# Севастопольский проспект        45
# Люблинская улица                44
# Алтуфьевское шоссе              43
# Зелёный проспект                42
# Рязанский проспект              42
# Мичуринский проспект            41
# Рублёвское шоссе                41
# Первомайская улица              40
# Щёлковское шоссе                39
# Шоссейная улица                 38
# ...

# %%
st_count[:5]
# Out:
# Street
# проезд без названия    510
# Варшавское шоссе       160
# Калужское шоссе        142
# шоссе Энтузиастов       85
# Боровское шоссе         79
# dtype: int64

# %%
pav_count = stations.groupby(['Street','Pavilion']).size()
pav_count
# Out:
# Street                         Pavilion
# 1-й Ботанический проезд        нет          1
# 1-й Боткинский проезд          да           2
# 1-й Варшавский проезд          да           2
# 1-й Вешняковский проезд        да           1
#                                нет          1
# 1-й Войковский проезд          да           1
#                                нет          1
# 1-й Волоколамский проезд       да           4
# 1-й Дачно-Мещерский проезд     нет          4
# 1-й Дербеневский переулок      да           1
#                                нет          2
# 1-й Западный проезд            да           2
# 1-й Капотнинский проезд        да          11
#                                нет          2
# 1-й Кожуховский проезд         да           1
# 1-й Котляковский переулок      нет          2
# 1-й Красногвардейский проезд   да           3
#                                нет          2
# 1-й Красногорский проезд       нет          1
# ...
